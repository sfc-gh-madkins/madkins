# %%
import sys
print(sys.executable)
sys.version
# Out:
# /Users/madkins/.pyenv/versions/3.8.16/envs/snowpark/bin/python3.8
# '3.8.16 (default, Mar  2 2023, 19:32:24) \n[Clang 14.0.0 (clang-1400.0.29.202)]'

# %%
from datetime import timedelta
from getpass import getpass
import json

import numpy as np
import pandas as pd
import pyarrow as pa

from snowflake.snowpark.session import Session
from snowflake.snowpark.functions import sproc

print('Numpy version: ' + np.__version__)
print('Pandas version: ' + pd.__version__)
print('PyArrow version: ' + pa.__version__)

import pykx as kx
print('PyKX version: ' + kx.__version__)
kx.q('\c 15 120');
# Out:
# Numpy version: 1.23.5
# Pandas version: 1.5.3
# PyArrow version: 8.0.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 16
#      13 print('Pandas version: ' + pd.__version__)
#      14 print('PyArrow version: ' + pa.__version__)
# ---> 16 import pykx as kx
#      17 print('PyKX version: ' + kx.__version__)
#      18 kx.q('\c 15 120');
#
# ModuleNotFoundError: No module named 'pykx'

# %%
accountname = 'xe85544.east-us-2.azure'
username = 'kx'
password = getpass('Password:')
license = getpass('License (base64):')

connection_parameters = {
    "account": accountname,
    "user": username,
    "password": password,
    "role": "SYSADMIN",
    "database": "KX",
    "schema": "BRUNO",
    "warehouse": "KX_OPT"
}

session = Session.builder.configs(connection_parameters).create()
# Out:
# Password:········
# License (base64):········

# %%
# %%time

session.table('trades').count()
# Out:
# CPU times: user 9.68 ms, sys: 6.79 ms, total: 16.5 ms
# Wall time: 280 ms
# 77026358

# %%
session.table('trades').limit(10).to_pandas()
# Out:
#               Time Exchange Symbol Sale Condition  Trade Volume  Trade Price  \
# 0  112834800054784        K    EDU              I             3        24.76
# 1  112834800836608        P    EDU              I            39        24.76
# 2  112834803282432        N    EDU            F I            10        24.77
# 3  112834803347712        Z    EDU            F I             3        24.77
# 4  112834804495360        T    EDU            F             100        24.77
# 5  112834807973632        N    EDU                          100        24.78
# 6  112834808023808        N    EDU                          100        24.78
# 7  112834808038912        N    EDU                          100        24.78
# 8  112834808043776        K    EDU                          100        24.78
# 9  112834861681408        U    EDU            F I             6        24.78
#
#   Trade Stop Stock Indicator  Trade Correction Indicator  Sequence Number  \
# 0                          N                           0          1141429
# 1                          N                           0          1141430
# 2                          N                           0          1141431
# 3                          N                           0          1141432
# 4                          N                           0          1141433
# 5                          N                           0          1141434
# 6                          N                           0          1141435
# 7                          N                           0          1141436
# 8                          N                           0          1141437
# 9                          N                           0          1141440
#
#          Trade Id Source of Trade Trade Reporting Facility  \
# 0  52983525300324               C                     None
# 1  52983543513399               C                     None
# 2  52983543256646               C                     None
# 3  52983525370689               C                     None
# 4  62879565892941               C                     None
# 5  52983543256647               C                     None
# 6  52983543256648               C                     None
# 7  52983543256649               C                     None
# 8  52983525300325               C                     None
# 9  53276003551830               C                     None
#
#   Participant Timestamp Trade Reporting Facility TRF Timestamp  \
# 0       112834799815000                                   None
# 1       112834800795648                                   None
# 2       112834803240448                                   None
# 3       112834803104000                                   None
# 4       112834804143912                                   None
# 5       112834807926272                                   None
# 6       112834807981824                                   None
# 7       112834807993600                                   None
# 8       112834807802000                                   None
# 9       112834861437919                                   None
#
#    Trade Through Exempt Indicator                         TTime
# 0                               0 2022-10-03 11:28:34.800054784
# 1                               0 2022-10-03 11:28:34.800836608
# 2                               1 2022-10-03 11:28:34.803282432
# 3                               1 2022-10-03 11:28:34.803347712
# 4                               1 2022-10-03 11:28:34.804495360
# 5                               0 2022-10-03 11:28:34.807973632
# 6                               0 2022-10-03 11:28:34.808023808
# 7                               0 2022-10-03 11:28:34.808038912
# 8                               0 2022-10-03 11:28:34.808043776
# 9                               1 2022-10-03 11:28:34.861681408

# %%
# %%time

session.table('quotes').count()
# Out:
# CPU times: user 11.1 ms, sys: 3.28 ms, total: 14.4 ms
# Wall time: 442 ms
# 1541781424

# %%
session.table('quotes').limit(10).to_pandas()
# Out:
#               Time Exchange Symbol  Bid_Price  Bid_Size  Offer_Price  \
# 0  093202252432958        Q   AAPL     138.09       1.0       138.13
# 1  093202252485709        Q   AAPL     138.09       1.0       138.12
# 2  093202252530211        Q   AAPL     138.09       1.0       138.13
# 3  093202252581105        Q   AAPL     138.09       1.0       138.12
# 4  093202252629599        Q   AAPL     138.09       1.0       138.13
# 5  093202252681162        Q   AAPL     138.09       1.0       138.12
# 6  093202252730407        Q   AAPL     138.09       1.0       138.13
# 7  093202252781139        Q   AAPL     138.09       1.0       138.12
# 8  093202252828957        Q   AAPL     138.09       1.0       138.13
# 9  093202252879829        Q   AAPL     138.09       1.0       138.12
#
#    Offer_Size Quote_Condition  Sequence_Number National_BBO_Ind  ...  \
# 0         1.0               R        1879559.0                0  ...
# 1         1.0               R        1879560.0                0  ...
# 2         1.0               R        1879561.0                0  ...
# 3         1.0               R        1879562.0                0  ...
# 4         1.0               R        1879563.0                0  ...
# 5         1.0               R        1879564.0                0  ...
# 6         1.0               R        1879565.0                0  ...
# 7         1.0               R        1879566.0                0  ...
# 8         1.0               R        1879567.0                0  ...
# 9         1.0               R        1879568.0                0  ...
#
#   Retail_Interest_Indicator Short_Sale_Restriction_Indicator  \
# 0                      None                                0
# 1                      None                                0
# 2                      None                                0
# 3                      None                                0
# 4                      None                                0
# 5                      None                                0
# 6                      None                                0
# 7                      None                                0
# 8                      None                                0
# 9                      None                                0
#
#   LULD_BBO_Indicator SIP_Generated_Message_Identifier  \
# 0               None                             None
# 1               None                             None
# 2               None                             None
# 3               None                             None
# 4               None                             None
# 5               None                             None
# 6               None                             None
# 7               None                             None
# 8               None                             None
# 9               None                             None
#
#   National_BBO_LULD_Indicator Participant_Timestamp FINRA_ADF_Timestamp  \
# 0                           A       093202252421231                None
# 1                           A       093202252471839                None
# 2                           A       093202252518532                None
# 3                           A       093202252569222                None
# 4                           A       093202252617834                None
# 5                           A       093202252668777                None
# 6                           A       093202252718048                None
# 7                           A       093202252768107                None
# 8                           A       093202252817512                None
# 9                           A       093202252867592                None
#
#   FINRA_ADF_Market_Participant_Quote_Indicator Security_Status_Indicator  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# 5                                         None
# 6                                         None
# 7                                         None
# 8                                         None
# 9                                         None
#
#                           TTime
# 0 2022-10-03 09:32:02.252432958
# 1 2022-10-03 09:32:02.252485709
# 2 2022-10-03 09:32:02.252530211
# 3 2022-10-03 09:32:02.252581105
# 4 2022-10-03 09:32:02.252629599
# 5 2022-10-03 09:32:02.252681162
# 6 2022-10-03 09:32:02.252730407
# 7 2022-10-03 09:32:02.252781139
# 8 2022-10-03 09:32:02.252828957
# 9 2022-10-03 09:32:02.252879829
#
# [10 rows x 24 columns]

# %%
# %%time

def business_logic(t, q):
    from datetime import timedelta

    q['mid'] = (q['ask_price'] + q['bid_price']) / 2
    qq = q[['symbol', 'time', 'mid']]

    tt = t[['symbol', 'time']].copy()
    tt['time'] += timedelta(seconds=1)
    t['tp1s'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] += timedelta(seconds=5)
    t['tp5s'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] += timedelta(seconds=10)
    t['tp10s'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] += timedelta(minutes=1)
    t['tp1m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] += timedelta(minutes=5)
    t['tp5m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] += timedelta(minutes=10)
    t['tp10m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] += timedelta(minutes=30)
    t['tp30m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']


    tt = t[['symbol', 'time']].copy()
    tt['time'] -= timedelta(seconds=1)
    t['tm1s'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] -= timedelta(seconds=5)
    t['tm5s'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] -= timedelta(seconds=10)
    t['tm10s'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']
    
    tt = t[['symbol', 'time']].copy()
    tt['time'] -= timedelta(minutes=1)
    t['tm1m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] -= timedelta(minutes=5)
    t['tm5m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] -= timedelta(minutes=10)
    t['tm10m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    tt = t[['symbol', 'time']].copy()
    tt['time'] -= timedelta(minutes=30)
    t['tm30m'] = pd.merge_asof(tt, qq, on='time', by='symbol')['mid']

    t['time'] = t['time'].astype('uint64')

    return t


@sproc(packages=['snowflake-snowpark-python', 'numpy', 'pandas', 'pyarrow'])
def my_pandas_procedure(session: Session) -> str:
    import json, time
    
    tstart = time.perf_counter()
    select_columns = ['"TTime"', '"Symbol"', '"Trade Volume"', '"Trade Price"']
    trades = session.table('trades').select(select_columns).order_by('"TTime"').to_pandas()
    trades.columns = ['time', 'symbol', 'volume', 'price']
    tend = time.perf_counter()
    tloadtrades = tend - tstart

    tstart = time.perf_counter()
    select_columns = ['"TTime"', '"Symbol"', '"Bid_Size"', '"Bid_Price"', '"Offer_Size"', '"Offer_Price"']
    quotes = session.table('quotes').select(select_columns).order_by('"TTime"').to_pandas()
    quotes.columns = ['time', 'symbol', 'ask_volume', 'ask_price', 'bid_volume', 'bid_price']
    tend = time.perf_counter()
    tloadquotes = tend - tstart

    tstart = time.perf_counter()
    output = business_logic(trades, quotes)
    tend = time.perf_counter()
    tpdalgo = tend - tstart
    
    tstart = time.perf_counter()
    session.write_pandas(output, 'OUTPUT_PANDAS', overwrite=True, chunk_size=1000000, compression='snappy')
    tend = time.perf_counter()
    tout = tend - tstart
        
    return json.dumps(dict(rows=len(output),
                           tloadtrades=tloadtrades,
                           tloadquotes=tloadquotes,
                           tpdalgo=tpdalgo,
                           tout=tout))
# Out:
# CPU times: user 80.5 ms, sys: 18.5 ms, total: 99 ms
# Wall time: 5.44 s

# %%
# %%time

rez = my_pandas_procedure()
rez = json.loads(rez)
rez
# Out:
# CPU times: user 480 ms, sys: 128 ms, total: 608 ms
# Wall time: 1h 10min 56s
# {'rows': 77026358,
#  'tloadtrades': 58.051440508999804,
#  'tloadquotes': 1228.2382535439992,
#  'tpdalgo': 2842.166595957,
#  'tout': 125.41016308399958}

# %%
# %%time

@sproc(packages=['snowflake-snowpark-python', 'numpy', 'pandas', 'pyarrow'],
       imports=['@~/kx/pykx-package.zip', '@~/kx/01_interval_returns.q_', '@~/kx/k4.lic'])
def my_pykx_procedure(session: Session) -> str:
    import base64, json, os, shutil, sys, time, zipfile
   
    ## CUSTOM SETUP OF PyKX (won't be needed when PyKX is available on Anaconda)
    tstart = time.perf_counter()
    if not os.path.exists('/tmp/k4.lic'):
        import_dir = sys._xoptions.get("snowflake_import_directory")
        lib = 'pykx-package.zip'
        lib_path = os.path.join(import_dir, lib)
        load_path = '/tmp/pykx-package/'

        if os.path.exists('/tmp/pykx-package'):
            shutil.rmtree('/tmp/pykx-package')
            time.sleep(0)
        with zipfile.ZipFile(lib_path, 'r') as zip_ref:
            zip_ref.extractall('/tmp/pykx-package')

        sys.path.insert(0, '/tmp/pykx-package')
        
        shutil.copyfile(os.path.join(import_dir, '01_interval_returns.q_'), '/tmp/01_interval_returns.q_')

        with open('/tmp/k4.lic', 'wb') as f:
            f.write(base64.b64decode(license))
    tend = time.perf_counter()
    tpykxinstall = tend - tstart
    ## END

    tstart = time.perf_counter()
    os.environ['QHOME'] = ''
    os.environ['QLIC'] = '/tmp'

    os.environ['PYKX_LOAD_PYARROW_UNSAFE'] = '1'
    os.environ['PYKX_NOQCE'] = '1'
    os.environ['SKIP_UNDERQ'] = '1'
    os.environ['IGNORE_QHOME'] = '1'
    os.environ['QARGS'] = '--licensed'
    
    import pykx as kx
    tend = time.perf_counter()
    tpykximport = tend - tstart
    
    tstart = time.perf_counter()
    select_columns = ['"TTime"', '"Symbol"', '"Trade Volume"', '"Trade Price"']
    trades = session.table('trades').select(select_columns).order_by('"TTime"').to_pandas()
    trades.columns = ['time', 'symbol', 'volume', 'price']
    tend = time.perf_counter()
    tloadtrades = tend - tstart
    
    tstart = time.perf_counter()
    kx.q['trades'] = trades
    del trades
    tend = time.perf_counter()
    ttoqtrades = tend - tstart

    tstart = time.perf_counter()
    select_columns = ['"TTime"', '"Symbol"', '"Bid_Size"', '"Bid_Price"', '"Offer_Size"', '"Offer_Price"']
    quotes = session.table('quotes').select(select_columns).order_by('"TTime"').to_pandas()
    quotes.columns = ['time', 'symbol', 'ask_volume', 'ask_price', 'bid_volume', 'bid_price']
    tend = time.perf_counter()
    tloadquotes = tend - tstart
    
    tstart = time.perf_counter()
    kx.q['quotes'] = quotes
    del quotes
    tend = time.perf_counter()
    ttoqquotes = tend - tstart

    tstart = time.perf_counter()
    kx.q('\l /tmp/01_interval_returns.q_')  # Run a locked q script to apply the business logic
    tend = time.perf_counter()
    tqalgo = tend - tstart
    
    tstart = time.perf_counter()
    output = kx.q('t').pd()
    tend = time.perf_counter()
    ttopd = tend - tstart
    
    tstart = time.perf_counter()
    session.write_pandas(output, 'OUTPUT', overwrite=True, chunk_size=1000000, compression='snappy')
    tend = time.perf_counter()
    tout = tend - tstart
    
    return json.dumps(dict(rows=len(output),
                           tpykxinstall=tpykxinstall,
                           tpykximport=tpykximport, 
                           tloadtrades=tloadtrades,
                           tloadquotes=tloadquotes,
                           ttoqtrades=ttoqtrades,
                           ttoqquotes=ttoqquotes,
                           tqalgo=tqalgo,
                           ttopd=ttopd,
                           tout=tout))
# Out:
# Failed to execute query [queryID: 01abf432-0b04-78b2-0003-0de2002804ce]
# CREATE
# TEMPORARY  PROCEDURE "KX"."BRUNO".SNOWPARK_TEMP_PROCEDURE_BS7RPTII83()
# RETURNS STRING
# LANGUAGE PYTHON
# RUNTIME_VERSION=3.8
# IMPORTS=('@~/kx/pykx-package.zip','@~/kx/01_interval_returns.q_','@~/kx/k4.lic','@"KX"."BRUNO".SNOWPARK_TEMP_STAGE_3WJG00LTL4/KXBRUNOSNOWPARK_TEMP_PROCEDURE_BS7RPTII83_948793065530730508/udf_py_754430782.zip')
# PACKAGES=('snowflake-snowpark-python','numpy','pandas','pyarrow','cloudpickle==2.0.0')
# HANDLER='udf_py_754430782.compute'
# EXECUTE AS OWNER
#
#
#
# 091016 (22000): Remote file 'kx/k4.lic' was not found. If you are running a copy command, please make sure files are not deleted when they are being loaded or files are not being loaded into two different tables concurrently with auto purge option.
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# File <timed exec>:3
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/stored_procedure.py:420, in StoredProcedureRegistration.register(self, func, return_type, input_types, name, is_permanent, stage_location, imports, packages, replace, parallel, execute_as, strict, statement_params)
#     415 check_register_args(
#     416     TempObjectType.PROCEDURE, name, is_permanent, stage_location, parallel
#     417 )
#     419 # register stored procedure
# --> 420 return self._do_register_sp(
#     421     func,
#     422     return_type,
#     423     input_types,
#     424     name,
#     425     stage_location,
#     426     imports,
#     427     packages,
#     428     replace,
#     429     parallel,
#     430     strict,
#     431     statement_params=statement_params,
#     432     execute_as=execute_as,
#     433     api_call_source="StoredProcedureRegistration.register",
#     434 )
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/stored_procedure.py:630, in StoredProcedureRegistration._do_register_sp(self, func, return_type, input_types, sp_name, stage_location, imports, packages, replace, parallel, strict, statement_params, execute_as, api_call_source)
#     626     tb = sys.exc_info()[2]
#     627     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     628         pe
#     629     )
# --> 630     raise ne.with_traceback(tb) from None
#     631 except BaseException:
#     632     raised = True
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/stored_procedure.py:604, in StoredProcedureRegistration._do_register_sp(self, func, return_type, input_types, sp_name, stage_location, imports, packages, replace, parallel, strict, statement_params, execute_as, api_call_source)
#     602 raised = False
#     603 try:
# --> 604     create_python_udf_or_sp(
#     605         session=self._session,
#     606         return_type=return_type,
#     607         input_args=input_args,
#     608         handler=handler,
#     609         object_type=TempObjectType.PROCEDURE,
#     610         object_name=udf_name,
#     611         all_imports=all_imports,
#     612         all_packages=all_packages,
#     613         is_temporary=stage_location is None,
#     614         replace=replace,
#     615         inline_python_code=code,
#     616         execute_as=execute_as,
#     617         api_call_source=api_call_source,
#     618         strict=strict,
#     619     )
#     620 # an exception might happen during registering a stored procedure
#     621 # (e.g., a dependency might not be found on the stage),
#     622 # then for a permanent stored procedure, we should delete the uploaded
#     623 # python file and raise the exception
#     624 except ProgrammingError as pe:
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/udf_utils.py:731, in create_python_udf_or_sp(session, return_type, input_args, handler, object_type, object_name, all_imports, all_packages, is_temporary, replace, inline_python_code, execute_as, api_call_source, strict, secure)
#     718     strict_as_sql = "\nSTRICT" if strict else ""
#     720     create_query = f"""
#     721 CREATE{" OR REPLACE " if replace else ""}
#     722 {"TEMPORARY" if is_temporary else ""} {"SECURE" if secure else ""} {object_type.value} {object_name}({sql_func_args})
#    (...)
#     729 {inline_python_code_in_sql}
#     730 """
# --> 731     session._run_query(create_query, is_ddl_on_temp_object=is_temporary)
#     733     # fire telemetry after _run_query is successful
#     734     api_call_source = api_call_source or "_internal.create_python_udf_or_sp"
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/session.py:1142, in Session._run_query(self, query, is_ddl_on_temp_object)
#    1141 def _run_query(self, query: str, is_ddl_on_temp_object: bool = False) -> List[Any]:
# -> 1142     return self._conn.run_query(query, is_ddl_on_temp_object=is_ddl_on_temp_object)[
#    1143         "data"
#    1144     ]
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:104, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#     103 except Exception as ex:
# --> 104     raise ex
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:98, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      96     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#      97 try:
# ---> 98     return func(*args, **kwargs)
#      99 except ReauthenticationRequest as ex:
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:331, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     329     query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     330     logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 331     raise ex
#     333 # fetch_pandas_all/batches() only works for SELECT statements
#     334 # We call fetchall() if fetch_pandas_all/batches() fails,
#     335 # because when the query plan has multiple queries, it will
#     336 # have non-select statements, and it shouldn't fail if the user
#     337 # calls to_pandas() to execute the query.
#     338 if block:
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:315, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     313     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     314 if block:
# --> 315     results_cursor = self._cursor.execute(query, **kwargs)
#     316     self.notify_query_listeners(
#     317         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     318     )
#     319     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/cursor.py:827, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream, num_statements)
#     823     is_integrity_error = (
#     824         code == "100072"
#     825     )  # NULL result in a non-nullable column
#     826     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 827     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     828 return self
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:275, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     252 @staticmethod
#     253 def errorhandler_wrapper(
#     254     connection: SnowflakeConnection | None,
#    (...)
#     257     error_value: dict[str, str | bool | int],
#     258 ) -> None:
#     259     """Error handler wrapper that calls the errorhandler method.
#     260
#     261     Args:
#    (...)
#     272         exception to the first handler in that order.
#     273     """
# --> 275     handed_over = Error.hand_to_other_handler(
#     276         connection,
#     277         cursor,
#     278         error_class,
#     279         error_value,
#     280     )
#     281     if not handed_over:
#     282         raise Error.errorhandler_make_exception(
#     283             error_class,
#     284             error_value,
#     285         )
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:330, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     328 if cursor is not None:
#     329     cursor.messages.append((error_class, error_value))
# --> 330     cursor.errorhandler(connection, cursor, error_class, error_value)
#     331     return True
#     332 elif connection is not None:
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:209, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     191 @staticmethod
#     192 def default_errorhandler(
#     193     connection: SnowflakeConnection,
#    (...)
#     196     error_value: dict[str, str],
#     197 ) -> None:
#     198     """Default error handler that raises an error.
#     199
#     200     Args:
#    (...)
#     207         A Snowflake error.
#     208     """
# --> 209     raise error_class(
#     210         msg=error_value.get("msg"),
#     211         errno=error_value.get("errno"),
#     212         sqlstate=error_value.get("sqlstate"),
#     213         sfqid=error_value.get("sfqid"),
#     214         done_format_msg=error_value.get("done_format_msg"),
#     215         connection=connection,
#     216         cursor=cursor,
#     217     )
#
# SnowparkSQLException: (1304): 01abf432-0b04-78b2-0003-0de2002804ce: 091016 (22000): Remote file 'kx/k4.lic' was not found. If you are running a copy command, please make sure files are not deleted when they are being loaded or files are not being loaded into two different tables concurrently with auto purge option.

# %%
# %%time

rez = my_pykx_procedure()
rez = json.loads(rez)
rez
# Out:
# Failed to execute query [queryID: 01abf432-0b04-78dd-0003-0de200281446] CALL "KX"."BRUNO".SNOWPARK_TEMP_PROCEDURE_EKM4RSPZGE()
# 000603 (XX000): SQL execution internal error:
# Processing aborted due to error 300010:1231732863; incident 9384228.
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/stored_procedure.py:87, in StoredProcedure.__call__(self, session, *args)
#      80     raise ValueError(
#      81         f"Incorrect number of arguments passed to the stored procedure. Expected: {len(self._input_types)}, Found: {len(args)}"
#      82     )
#      84 session._conn._telemetry_client.send_function_usage_telemetry(
#      85     "StoredProcedure.__call__", TelemetryField.FUNC_CAT_USAGE.value
#      86 )
# ---> 87 return session.call(self.name, *args)
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/session.py:1844, in Session.call(self, sproc_name, *args)
#    1842 df = self.sql(f"CALL {sproc_name}({', '.join(sql_args)})")
#    1843 set_api_call_source(df, "Session.call")
# -> 1844 return df.collect()[0][0]
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/telemetry.py:138, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     135 @functools.wraps(func)
#     136 def wrap(*args, **kwargs):
#     137     with args[0]._session.query_history() as query_history:
# --> 138         result = func(*args, **kwargs)
#     139     plan = args[0]._select_statement or args[0]._plan
#     140     api_calls = [
#     141         *plan.api_calls,
#     142         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     143     ]
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/dataframe.py:546, in DataFrame.collect(self, statement_params, block)
#     530 @df_collect_api_telemetry
#     531 def collect(
#     532     self, *, statement_params: Optional[Dict[str, str]] = None, block: bool = True
#     533 ) -> Union[List[Row], AsyncJob]:
#     534     """Executes the query representing this DataFrame and returns the result as a
#     535     list of :class:`Row` objects.
#     536
#    (...)
#     544         :meth:`collect_nowait()`
#     545     """
# --> 546     return self._internal_collect_with_tag_no_telemetry(
#     547         statement_params=statement_params, block=block
#     548     )
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/dataframe.py:581, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type)
#     571 def _internal_collect_with_tag_no_telemetry(
#     572     self,
#     573     *,
#    (...)
#     579     # we should always call this method instead of collect(), to make sure the
#     580     # query tag is set properly.
# --> 581     return self._session._conn.execute(
#     582         self._plan,
#     583         block=block,
#     584         data_type=data_type,
#     585         _statement_params=create_or_update_statement_params_with_query_tag(
#     586             statement_params, self._session.query_tag, SKIP_LEVELS_THREE
#     587         ),
#     588     )
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:404, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, **kwargs)
#     400 if is_in_stored_procedure() and not block:  # pragma: no cover
#     401     raise NotImplementedError(
#     402         "Async query is not supported in stored procedure yet"
#     403     )
# --> 404 result_set, result_meta = self.get_result_set(
#     405     plan, to_pandas, to_iter, **kwargs, block=block, data_type=data_type
#     406 )
#     407 if not block:
#     408     return result_set
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:156, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     152 else:
#     153     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     154         e
#     155     )
# --> 156     raise ne.with_traceback(tb) from None
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:89, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      87 def wrap(*args, **kwargs):
#      88     try:
# ---> 89         return func(*args, **kwargs)
#      90     except snowflake.connector.errors.ProgrammingError as e:
#      91         tb = sys.exc_info()[2]
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:492, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, **kwargs)
#     490 for holder, id_ in placeholders.items():
#     491     final_query = final_query.replace(holder, id_)
# --> 492 result = self.run_query(
#     493     final_query,
#     494     to_pandas,
#     495     to_iter and (i == len(plan.queries) - 1),
#     496     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     497     block=not is_last,
#     498     data_type=data_type,
#     499     async_job_plan=plan,
#     500     **kwargs,
#     501 )
#     502 placeholders[query.query_id_place_holder] = (
#     503     result["sfqid"] if not is_last else result.query_id
#     504 )
#     505 result_meta = self._cursor.description
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:104, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#     103 except Exception as ex:
# --> 104     raise ex
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:98, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      96     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#      97 try:
# ---> 98     return func(*args, **kwargs)
#      99 except ReauthenticationRequest as ex:
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:331, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     329     query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     330     logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 331     raise ex
#     333 # fetch_pandas_all/batches() only works for SELECT statements
#     334 # We call fetchall() if fetch_pandas_all/batches() fails,
#     335 # because when the query plan has multiple queries, it will
#     336 # have non-select statements, and it shouldn't fail if the user
#     337 # calls to_pandas() to execute the query.
#     338 if block:
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:315, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     313     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     314 if block:
# --> 315     results_cursor = self._cursor.execute(query, **kwargs)
#     316     self.notify_query_listeners(
#     317         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     318     )
#     319     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/cursor.py:827, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream, num_statements)
#     823     is_integrity_error = (
#     824         code == "100072"
#     825     )  # NULL result in a non-nullable column
#     826     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 827     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     828 return self
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:275, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     252 @staticmethod
#     253 def errorhandler_wrapper(
#     254     connection: SnowflakeConnection | None,
#    (...)
#     257     error_value: dict[str, str | bool | int],
#     258 ) -> None:
#     259     """Error handler wrapper that calls the errorhandler method.
#     260
#     261     Args:
#    (...)
#     272         exception to the first handler in that order.
#     273     """
# --> 275     handed_over = Error.hand_to_other_handler(
#     276         connection,
#     277         cursor,
#     278         error_class,
#     279         error_value,
#     280     )
#     281     if not handed_over:
#     282         raise Error.errorhandler_make_exception(
#     283             error_class,
#     284             error_value,
#     285         )
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:330, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     328 if cursor is not None:
#     329     cursor.messages.append((error_class, error_value))
# --> 330     cursor.errorhandler(connection, cursor, error_class, error_value)
#     331     return True
#     332 elif connection is not None:
#
# File ~/.pyenv/versions/3.8.16/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:209, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     191 @staticmethod
#     192 def default_errorhandler(
#     193     connection: SnowflakeConnection,
#    (...)
#     196     error_value: dict[str, str],
#     197 ) -> None:
#     198     """Default error handler that raises an error.
#     199
#     200     Args:
#    (...)
#     207         A Snowflake error.
#     208     """
# --> 209     raise error_class(
#     210         msg=error_value.get("msg"),
#     211         errno=error_value.get("errno"),
#     212         sqlstate=error_value.get("sqlstate"),
#     213         sfqid=error_value.get("sfqid"),
#     214         done_format_msg=error_value.get("done_format_msg"),
#     215         connection=connection,
#     216         cursor=cursor,
#     217     )
#
# SnowparkSQLException: (1304): 01abf432-0b04-78dd-0003-0de200281446: 000603 (XX000): SQL execution internal error:
# Processing aborted due to error 300010:1231732863; incident 9384228.
