# %%
import pickle
import random
import string
from typing import List

from snowflake.ml.transformers.preprocessing import standard_scaler, ordinal_encoder
from snowflake.ml.transformers import pipeline
from snowflake.ml.utils import connection_params
#from snowflake.ml.fileset import fileset
from snowflake import snowpark
from snowflake.snowpark import DataFrame
from snowflake.snowpark import functions as F
from snowflake.snowpark.functions import col, iff, cast, row_number
import pandas as pd
import pyarrow as pa
import os

# %%
connection_parameters = {
    "account": "VUA92284",
    "user": "snowflake_nvidia",
    "password": os.environ['SNOWFLAKE_TEMP_PASSWORD'],
    "role": "SNOWFLAKE_NVIDIA",  # optional
    "warehouse": "SNOWFLAKE_NVIDIA",  # medium snowpark-optimized
    "database": "SNOWFLAKE_NVIDIA",  
    "schema": "PUBLIC",  
  }
session = snowpark.Session.builder.configs(connection_parameters).create()

# %%
# Criteo dataset

_NUMERICAL_FEATURES = [f"I{i}" for i in range(1, 14)]
_CATEGORICAL_FEATURES = [f"C{i}" for i in range(1, 27)]
_LABEL = "LABEL"

# I sample the data before I'm confident that training works.
_SAMPLE_SIZE = 1000000

# %%
# "Featurization"
# In reality, the SQL below should be much more complicated and would involve joins.

select_columns = (
    [_LABEL]
    + _NUMERICAL_FEATURES
    + _CATEGORICAL_FEATURES
)
limit = f"limit {_SAMPLE_SIZE}" if _SAMPLE_SIZE else ""
all_data = session.sql(f'''select {','.join(select_columns)} from "criteo_day_0" {limit}''')
[train_data, eval_data, test_data] = all_data.random_split([0.8, 0.1, 0.1])

# %%
all_data.limit(5).to_pandas()
# Out:
#    LABEL   I1      I2   I3    I4    I5   I6   I7  I8  I9  I10  I11      I12  \
# 0      0  1.0   280.0  2.0  20.0  10.0  0.0  0.0   0   2  0.0  4.0   4036.0
# 1      0  NaN    17.0  NaN   5.0   1.0  NaN  0.0  -1   0  NaN  1.0  20314.0
# 2      0  4.0   315.0  7.0   8.0  10.0  5.0  0.0  90   8  1.0  4.0    276.0
# 3      0  2.0  1596.0  7.0  99.0  12.0  0.0  0.0   0  19  0.0  8.0   2764.0
# 4      0  1.0     3.0  NaN   NaN   NaN  NaN  NaN   2   4  NaN  NaN   1234.0
#
#    I13
# 0  2.0
# 1  NaN
# 2  8.0
# 3  7.0
# 4  NaN

# %%
# Feature engineering functions
def fit_transformers(data_df: DataFrame) -> pipeline.Pipeline:
    p = pipeline.Pipeline(
        [
            (
                "scale_to_std",
                standard_scaler.StandardScaler(
                    input_cols=_NUMERICAL_FEATURES,
                    output_cols=[f"scaled_{f}" for f in _NUMERICAL_FEATURES],
                ),
            ),
            (
                "vocab",
                ordinal_encoder.OrdinalEncoder(
                    input_cols=_CATEGORICAL_FEATURES,
                    output_cols=[f"vocab_{f}" for f in _CATEGORICAL_FEATURES],
                    encoded_missing_value=-1,
                    unknown_value=-1,
                    handle_unknown="use_encoded_value",
                ),
            ),
        ]
    )

    return p.fit(data_df)


def preprocess_with_transformers(
    fitted_pipeline: pipeline.Pipeline, data_df: DataFrame
) -> DataFrame:
    transformed_data = fitted_pipeline.transform(data_df)
    # keep only transformed columns
    transformed_data = transformed_data.select(
        [col(f"scaled_{f}").alias(f) for f in _NUMERICAL_FEATURES]
        + [col(f"vocab_{f}").alias(f) for f in _CATEGORICAL_FEATURES]
        + [_LABEL]
    )
    # the following are either not implemented or something we have to fight..

    transformed_data = (
        transformed_data.na.fill(0)
        # 1. replace negative vocab values with n_vocab (since 0...n_vocab-1 are already occupied)
        # 2. cast vocab values to int (originally float)
        .select(
            [
                cast(
                    iff(
                        col(f) == -1.0,
                        len(fitted_pipeline.steps[1][1].categories_[f]),
                        col(f),
                    ),
                    "int",
                ).alias(f)
                for f in _CATEGORICAL_FEATURES
            ]
            + _NUMERICAL_FEATURES
            + [cast(_LABEL, "float").alias(_LABEL)]
        )
    )

    return transformed_data

# %%
# fit using only training split but transform all splits.
p = fit_transformers(train_data)

#preprocessed_train_data = preprocess_with_transformers(p, train_data)
#preprocessed_eval_data = preprocess_with_transformers(p, eval_data)
#preprocessed_test_data = preprocess_with_transformers(p, test_data)
# Out:
# Failed to execute query [queryID: 01aa9f79-0402-9b75-002a-c9030e12f396] ( SELECT "'C1'" AS "_COLUMN_NAME", "C1" AS "'_CATEGORY_vludloz4cs'", " CAST ((row_number() OVER (  ORDER BY ""C1"" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT)" AS "_INDEX" FROM ( SELECT 'C1', "C1",  CAST ((row_number() OVER (  ORDER BY "C1" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT) FROM ( SELECT  *  FROM ( SELECT "C1" FROM ( SELECT "C1" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABLE_9LRUMHHV73 WHERE (("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" >= 0 :: INT) AND ("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" < 800000 :: INT)))) GROUP BY "C1") WHERE "C1" IS NOT NULL ORDER BY "C1" ASC NULLS FIRST))) UNION ( SELECT "'C1'" AS "_COLUMN_NAME", "C1" AS "'_CATEGORY_vludloz4cs'", "-1 :: INT" AS "_INDEX" FROM ( SELECT 'C1', "C1", -1 :: INT FROM ( SELECT  *  FROM ( SELECT "C1" FROM ( SELECT "C1" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABLE_9LRUMHHV73 WHERE (("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" >= 0 :: INT) AND ("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" < 800000 :: INT)))) GROUP BY "C1") WHERE "C1" IS NULL))) UNION ( SELECT "_COLUMN_NAME", "'_CATEGORY_vludloz4cs'", "_INDEX" FROM (( SELECT "'C2'" AS "_COLUMN_NAME", "C2" AS "'_CATEGORY_vludloz4cs'", " CAST ((row_number() OVER (  ORDER BY ""C2"" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT)" AS "_INDEX" FROM ( SELECT 'C2', "C2",  CAST ((row_number() OVER (  ORDER BY "C2" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT) FROM ( SELECT  *  FROM ( SELECT "C2" FROM ( SELECT "C2" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABLE_9LRUMHHV73 WHERE (("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" >= 0 :: INT) AND ("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" < 800000 :: INT)))) GROUP BY "C2") WHERE "C2" IS NOT NULL ORDER BY "C2" ASC NULLS FIRST))) UNION ( SELECT "'C2'" AS "_COLUMN_NAME", "C2" AS "'_CATEGORY_vludloz4cs'", "-1 :: INT" AS "_INDEX" FROM ( SELECT 'C2', "C2", -1 :: INT FROM ( SELECT  *  FROM ( SELECT "C2" FROM ( SELECT "C2" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABLE_9LRUMHHV73 WHERE (("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" >= 0 :: INT) AND ("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" < 800000 :: INT)))) GROUP BY "C2") WHERE "C2" IS NULL))))) UNION ( SELECT "_COLUMN_NAME", "'_CATEGORY_vludloz4cs'", "_INDEX" FROM (( SELECT "'C3'" AS "_COLUMN_NAME", "C3" AS "'_CATEGORY_vludloz4cs'", " CAST ((row_number() OVER (  ORDER BY ""C3"" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT)" AS "_INDEX" FROM ( SELECT 'C3', "C3",  CAST ((row_number() OVER (  ORDER BY "C3" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT) FROM ( SELECT  *  FROM ( SELECT "C3" FROM ( SELECT "C3" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABLE_9LRUMHHV73 WHERE (("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" >= 0 :: INT) AND ("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" < 800000 :: INT)))) GROUP BY "C3") WHERE "C3" IS NOT NULL ORDER BY "C3" ASC NULLS FIRST))) UNION ( SELECT "'C3'" AS "_COLUMN_NAME", "C3" AS "'_CATEGORY_vludloz4cs'", "-1 :: INT" AS "_INDEX" FROM ( SELECT 'C3', "C3", -1 :: INT FROM ( SELECT  *  FROM ( SELECT "C3" FROM ( SELECT "C3" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABLE_9LRUMHHV73 WHERE (("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" >= 0 :: INT) AND ("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" < 800000 :: INT)))) GROUP BY "C3") WHERE "C3" IS NULL))))) UNION ( SELECT "_COLUMN_NAME", "'_CATEGORY_vludloz4cs'", "_INDEX" FROM (( SELECT "'C4'" AS "_COLUMN_NAME", "C4" AS "'_CATEGORY_vludloz4cs'", " CAST ((row_number() OVER (  ORDER BY ""C4"" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT)" AS "_INDEX" FROM ( SELECT 'C4', "C4",  CAST ((row_number() OVER (  ORDER BY "C4" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT) FROM ( SELECT  *  FROM ( SELECT "C4" FROM ( SELECT "C4" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABLE_9LRUMHHV73 WHERE (("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" >= 0 :: INT) AND ("SNOWPARK_TEMP_COLUMN_1TVRW0X3UZ" < 800000 :: INT)))) GROUP BY "C4") WHERE "C4" IS NOT NULL ORDER BY "C4" ASC NULLS FIRST))) UNION ( SELECT "'C4'" AS "_COLUMN_NAME", "C4" AS "'_CATEGORY_vludloz4cs'", "-1 :: INT" AS "_INDEX" FROM ( SELECT 'C4', "C4", -1 :: INT FROM ( SELECT  *  FROM ( SELECT "C4" FROM ( SELECT "C4" FROM ( SELECT  *  FROM SNOWPARK_TEMP_TABL ...
# 000904 (42000): SQL compilation error: error line 1 at position 69
# invalid identifier '" CAST ((row_number() OVER (  ORDER BY "C1" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT)"'
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[41], line 2
#       1 # fit using only training split but transform all splits.
# ----> 2 p = fit_transformers(train_data)
#       4 #preprocessed_train_data = preprocess_with_transformers(p, train_data)
#       5 #preprocessed_eval_data = preprocess_with_transformers(p, eval_data)
#       6 #preprocessed_test_data = preprocess_with_transformers(p, test_data)
#
# Cell In[40], line 25, in fit_transformers(data_df)
#       2 def fit_transformers(data_df: DataFrame) -> pipeline.Pipeline:
#       3     p = pipeline.Pipeline(
#       4         [
#       5             (
#    (...)
#      22         ]
#      23     )
# ---> 25     return p.fit(data_df)
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/ml/transformers/pipeline.py:126, in Pipeline.fit(self, dataset)
#     124 self._validate_steps()
#     125 dataset_copy = dataset
# --> 126 dataset_copy = self._fit_transform_dataset(dataset_copy)
#     128 estimator = self._get_estimator()
#     129 if estimator:
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/ml/transformers/pipeline.py:104, in Pipeline._fit_transform_dataset(self, dataset)
#     102         transformed_dataset = trans.fit_transform(transformed_dataset)
#     103     else:
# --> 104         trans.fit(transformed_dataset)
#     105         transformed_dataset = trans.transform(transformed_dataset)
#     107 return transformed_dataset
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/ml/transformers/preprocessing/ordinal_encoder.py:134, in OrdinalEncoder.fit(self, dataset)
#     132 self._validate_keywords()
#     133 super()._check_input_cols()
# --> 134 self._fit_category_state(dataset)
#     135 self._validate_unknown_value()
#     136 self._check_missing_categories()
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/ml/transformers/preprocessing/ordinal_encoder.py:162, in OrdinalEncoder._fit_category_state(self, dataset)
#     160 state_df = self._get_category_index_state_df(dataset)
#     161 statement_params = {"SNOWML": self.__class__.__name__, "METHOD": "FIT"}
# --> 162 self._state_pandas = state_df.to_pandas(statement_params=statement_params)
#     164 self._assign_categories()
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/telemetry.py:138, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     135 @functools.wraps(func)
#     136 def wrap(*args, **kwargs):
#     137     with args[0]._session.query_history() as query_history:
# --> 138         result = func(*args, **kwargs)
#     139     plan = args[0]._select_statement or args[0]._plan
#     140     api_calls = [
#     141         *plan.api_calls,
#     142         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     143     ]
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/dataframe.py:704, in DataFrame.to_pandas(self, statement_params, block, **kwargs)
#     678 @df_collect_api_telemetry
#     679 def to_pandas(
#     680     self,
#    (...)
#     684     **kwargs: Dict[str, Any],
#     685 ) -> Union["pandas.DataFrame", AsyncJob]:
#     686     """
#     687     Executes the query representing this DataFrame and returns the result as a
#     688     `Pandas DataFrame <https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html>`_.
#    (...)
#     702         :func:`Session.sql` can only be a SELECT statement.
#     703     """
# --> 704     result = self._session._conn.execute(
#     705         self._plan,
#     706         to_pandas=True,
#     707         block=block,
#     708         data_type=_AsyncResultType.PANDAS,
#     709         _statement_params=create_or_update_statement_params_with_query_tag(
#     710             statement_params, self._session.query_tag, SKIP_LEVELS_TWO
#     711         ),
#     712         **kwargs,
#     713     )
#     715     # if the returned result is not a pandas dataframe, raise Exception
#     716     # this might happen when calling this method with non-select commands
#     717     # e.g., session.sql("create ...").to_pandas()
#     718     if block:
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:406, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, **kwargs)
#     402 if is_in_stored_procedure() and not block:  # pragma: no cover
#     403     raise NotImplementedError(
#     404         "Async query is not supported in stored procedure yet"
#     405     )
# --> 406 result_set, result_meta = self.get_result_set(
#     407     plan, to_pandas, to_iter, **kwargs, block=block, data_type=data_type
#     408 )
#     409 if not block:
#     410     return result_set
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:107, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     103 if not match:  # pragma: no cover
#     104     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     105         e
#     106     )
# --> 107     raise ne.with_traceback(tb) from None
#     108 col = match.group(1)
#     109 children = [
#     110     arg for arg in args if isinstance(arg, SnowflakePlan)
#     111 ]
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:89, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      87 def wrap(*args, **kwargs):
#      88     try:
# ---> 89         return func(*args, **kwargs)
#      90     except snowflake.connector.errors.ProgrammingError as e:
#      91         tb = sys.exc_info()[2]
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:494, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, **kwargs)
#     492 for holder, id_ in placeholders.items():
#     493     final_query = final_query.replace(holder, id_)
# --> 494 result = self.run_query(
#     495     final_query,
#     496     to_pandas,
#     497     to_iter and (i == len(plan.queries) - 1),
#     498     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     499     block=not is_last,
#     500     data_type=data_type,
#     501     async_job_plan=plan,
#     502     **kwargs,
#     503 )
#     504 placeholders[query.query_id_place_holder] = (
#     505     result["sfqid"] if not is_last else result.query_id
#     506 )
#     507 result_meta = self._cursor.description
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:104, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#     103 except Exception as ex:
# --> 104     raise ex
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:98, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      96     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#      97 try:
# ---> 98     return func(*args, **kwargs)
#      99 except ReauthenticationRequest as ex:
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:333, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     331     query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     332     logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 333     raise ex
#     335 # fetch_pandas_all/batches() only works for SELECT statements
#     336 # We call fetchall() if fetch_pandas_all/batches() fails,
#     337 # because when the query plan has multiple queries, it will
#     338 # have non-select statements, and it shouldn't fail if the user
#     339 # calls to_pandas() to execute the query.
#     340 if block:
#
# File ~/Documents/snowpark-python/src/snowflake/snowpark/_internal/server_connection.py:317, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     315     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     316 if block:
# --> 317     results_cursor = self._cursor.execute(query, **kwargs)
#     318     self.notify_query_listeners(
#     319         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     320     )
#     321     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/cursor.py:827, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream, num_statements)
#     823     is_integrity_error = (
#     824         code == "100072"
#     825     )  # NULL result in a non-nullable column
#     826     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 827     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     828 return self
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:275, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     252 @staticmethod
#     253 def errorhandler_wrapper(
#     254     connection: SnowflakeConnection | None,
#    (...)
#     257     error_value: dict[str, str | bool | int],
#     258 ) -> None:
#     259     """Error handler wrapper that calls the errorhandler method.
#     260
#     261     Args:
#    (...)
#     272         exception to the first handler in that order.
#     273     """
# --> 275     handed_over = Error.hand_to_other_handler(
#     276         connection,
#     277         cursor,
#     278         error_class,
#     279         error_value,
#     280     )
#     281     if not handed_over:
#     282         raise Error.errorhandler_make_exception(
#     283             error_class,
#     284             error_value,
#     285         )
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:330, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     328 if cursor is not None:
#     329     cursor.messages.append((error_class, error_value))
# --> 330     cursor.errorhandler(connection, cursor, error_class, error_value)
#     331     return True
#     332 elif connection is not None:
#
# File ~/.pyenv/versions/3.8.13/envs/snowpark/lib/python3.8/site-packages/snowflake/connector/errors.py:209, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     191 @staticmethod
#     192 def default_errorhandler(
#     193     connection: SnowflakeConnection,
#    (...)
#     196     error_value: dict[str, str],
#     197 ) -> None:
#     198     """Default error handler that raises an error.
#     199
#     200     Args:
#    (...)
#     207         A Snowflake error.
#     208     """
# --> 209     raise error_class(
#     210         msg=error_value.get("msg"),
#     211         errno=error_value.get("errno"),
#     212         sqlstate=error_value.get("sqlstate"),
#     213         sfqid=error_value.get("sfqid"),
#     214         done_format_msg=error_value.get("done_format_msg"),
#     215         connection=connection,
#     216         cursor=cursor,
#     217     )
#
# SnowparkSQLException: (1304): 01aa9f79-0402-9b75-002a-c9030e12f396: 000904 (42000): SQL compilation error: error line 1 at position 69
# invalid identifier '" CAST ((row_number() OVER (  ORDER BY "C1" ASC NULLS FIRST ) - 1 :: INT) AS FLOAT)"'
